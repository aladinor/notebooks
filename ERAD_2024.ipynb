# %%
import kerchunk
import xarray as xr
from kerchunk.hdf import SingleHdf5ToZarr
from kerchunk.combine import MultiZarrToZarr
import fsspec
from glob import glob
import xradar as xd
import matplotlib.pyplot as plt
import cmweather
import numpy as np
import hvplot.xarray
import pyart
from xarray.core.datatree import DataTree
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
def fix_angle(ds):
    """
    Aligns the radar volumes
    """
    ds["time"] = ds.time.load()  # Convert time from dask to numpy

    start_ang = 0  # Set consistent start/end values
    stop_ang = 360

    # Find the median angle resolution
    angle_res = np.round(ds.azimuth.diff("azimuth").median(),2)
    
    # Determine whether the radar is spinning clockwise or counterclockwise
    median_diff = ds.azimuth.diff("time").median()
    ascending = median_diff > 0
    direction = 1 if ascending else -1

    # first find exact duplicates and remove
    ds = xd.util.remove_duplicate_rays(ds)

    # second reindex according to retrieved parameters
    ds = xd.util.reindex_angle(
        ds, start_ang, stop_ang, angle_res, direction, method="nearest"
    )

    ds = ds.expand_dims("volume_time")  # Expand for volumes for concatenation

    ds["volume_time"] = [np.nanmin(ds.time.values)]

    return ds

# %%
erad_files = glob("/media/alfonso/drive/Laura/ERAD/20240522_MeteoSwiss_ARPA_Lombardia/Data/Cband/MonteLema*.nc")
xband_files =glob("/media/alfonso/drive/Laura/ERAD/20240522_MeteoSwiss_ARPA_Lombardia/Data/Xband/DES_VOL_RAW*.nc")
xband_files[:1]
# Out:
# ['/media/alfonso/drive/Laura/ERAD/20240522_MeteoSwiss_ARPA_Lombardia/Data/Xband/DES_VOL_RAW_20240522_1745.nc']

# %%
radar = pyart.io.read_cfradial(xband_files[0])
list(radar.fields)
# Out:
# ['DBZ_TOT',
#  'DBZ',
#  'VEL',
#  'WIDTH',
#  'ZDR',
#  'KDP',
#  'RHOHV',
#  'PHIDP',
#  'HCLASS',
#  'MCSSX']

# %%
radar.info("compact")
# Out:
# altitude: <ndarray of type: float64 and shape: (1,)>
# altitude_agl: <ndarray of type: float64 and shape: (1,)>
# antenna_transition: <ndarray of type: int8 and shape: (2880,)>
# azimuth: <ndarray of type: float32 and shape: (2880,)>
# elevation: <ndarray of type: float32 and shape: (2880,)>
# fields:
# 	DBZ_TOT: <ndarray of type: float32 and shape: (2880, 416)>
# 	DBZ: <ndarray of type: float32 and shape: (2880, 416)>
# 	VEL: <ndarray of type: float32 and shape: (2880, 416)>
# 	WIDTH: <ndarray of type: float32 and shape: (2880, 416)>
# 	ZDR: <ndarray of type: float32 and shape: (2880, 416)>
# 	KDP: <ndarray of type: float32 and shape: (2880, 416)>
# 	RHOHV: <ndarray of type: float32 and shape: (2880, 416)>
# 	PHIDP: <ndarray of type: float32 and shape: (2880, 416)>
# 	HCLASS: <ndarray of type: float32 and shape: (2880, 416)>
# 	MCSSX: <ndarray of type: int16 and shape: (2880, 416)>
# fixed_angle: <ndarray of type: float32 and shape: (8,)>
# instrument_parameters:
# 	frequency: <ndarray of type: float32 and shape: (1,)>
# 	follow_mode: <ndarray of type: |S1 and shape: (8, 32)>
# 	pulse_width: <ndarray of type: float32 and shape: (2880,)>
# 	prt_mode: <ndarray of type: |S1 and shape: (8, 32)>
# 	prt: <ndarray of type: float32 and shape: (2880,)>
# 	prt_ratio: <ndarray of type: float32 and shape: (2880,)>
# 	polarization_mode: <ndarray of type: |S1 and shape: (8, 32)>
# 	nyquist_velocity: <ndarray of type: float32 and shape: (2880,)>
# 	unambiguous_range: <ndarray of type: float32 and shape: (2880,)>
# 	n_samples: <ndarray of type: int32 and shape: (2880,)>
# 	radar_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	radar_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	radar_beam_width_h: <ndarray of type: float32 and shape: (1,)>
# 	radar_beam_width_v: <ndarray of type: float32 and shape: (1,)>
# 	radar_rx_bandwidth: <ndarray of type: float32 and shape: (1,)>
# 	measured_transmit_power_v: <ndarray of type: float32 and shape: (2880,)>
# 	measured_transmit_power_h: <ndarray of type: float32 and shape: (2880,)>
# latitude: <ndarray of type: float64 and shape: (1,)>
# longitude: <ndarray of type: float64 and shape: (1,)>
# nsweeps: 8
# ngates: 416
# nrays: 2880
# radar_calibration:
# 	r_calib_time: <ndarray of type: |S1 and shape: (1, 32)>
# 	r_calib_pulse_width: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_xmit_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_waveguide_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_two_way_radome_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_mismatch_loss: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_k_squared_water: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_radar_constant_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_antenna_gain_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_i0_dbm_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_i0_dbm_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_i0_dbm_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_i0_dbm_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_gain_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_receiver_slope_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_dynamic_range_db_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_dynamic_range_db_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_dynamic_range_db_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_dynamic_range_db_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_base_dbz_1km_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vc: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_hx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_sun_power_vx: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_noise_source_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_power_measure_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_coupler_forward_loss_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_dbz_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_zdr_correction: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_ldr_correction_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_system_phidp: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_h: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_test_power_v: <ndarray of type: float32 and shape: (1,)>
# 	r_calib_index: <ndarray of type: int32 and shape: (2880,)>
# range: <ndarray of type: float32 and shape: (416,)>
# scan_rate: <ndarray of type: float32 and shape: (2880,)>
# scan_type: ppi
# sweep_end_ray_index: <ndarray of type: int32 and shape: (8,)>
# sweep_mode: <ndarray of type: |S1 and shape: (8, 32)>
# sweep_number: <ndarray of type: int32 and shape: (8,)>
# sweep_start_ray_index: <ndarray of type: int32 and shape: (8,)>
# target_scan_rate: <ndarray of type: float32 and shape: (8,)>
# time: <ndarray of type: float64 and shape: (2880,)>
# metadata:
# 	Conventions: CF-1.7
# 	Sub_conventions: CF-Radial instrument_parameters radar_parameters radar_calibration
# 	version: CF-Radial-1.4
# 	title: VOL_A
# 	institution:
# 	references: Conversion software: Radx::SigmetRadxFile
# 	source: Sigmet IRIS software
# 	comment:
# 	original_format: SIGMETRAW
# 	driver: RadxConvert(NCAR)
# 	created: 2024/05/22 18:13:40.651
# 	start_datetime: 2024-05-22T17:45:47Z
# 	time_coverage_start: 2024-05-22T17:45:47Z
# 	start_time: 2024-05-22 17:45:47.189
# 	end_datetime: 2024-05-22T17:48:20Z
# 	time_coverage_end: 2024-05-22T17:48:20Z
# 	end_time: 2024-05-22 17:48:20.543
# 	instrument_name: Desio_Radar
# 	site_name: Desio_Radar
# 	scan_name: VOL_A
# 	scan_id: 0
# 	platform_is_mobile: false
# 	n_gates_vary: false
# 	ray_times_increase: true
# 	NCO: netCDF Operators version 4.9.7 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)
# 	history: Wed May 22 18:13:42 2024: ncap2 -Os fixed_angle  (:)={0.7,1.3,3.0,5.0,7.0,10.0,15.0,25.0} /data/out/sigmet/realtime/20240522/DES/VOL/DES_VOL_RAW_20240522_1745.corr.nc /data/out/sigmet/realtime/20240522/DES/VOL/DES_VOL_RAW_20240522_1745.corr2.nc
# Wed May 22 18:13:41 2024: ncap2 -Os sweep_number  (:)={0,1,2,3,4,5,6,7} /data/out/sigmet/realtime/20240522/DES/VOL/DES_VOL_RAW_20240522_1745.nc /data/out/sigmet/realtime/20240522/DES/VOL/DES_VOL_RAW_20240522_1745.corr.nc
# Sigmet RAW file: ; get_percentile_nc.py: maxDBZInRaw = {"dbz99": "28.9", "dbzMax": "55.3"}; get_percentile_nc.py: legend MCSSX= {0: "NoMetClttr", 1: "NoMetBioExtd", 2: "MetRain", 3: "MetWetSnow", 4: "MetSnow", 5: "MetGraupel", 6: "MetHail"}; get_percentile_nc.py: countInRaw MCSSX= {"NoData": 800697, "NoMetClttr": 15422, "NoMetBioExtd": 31861, "MetRain": 40849, "MetWetSnow": 16560, "MetSnow": 129378, "MetGraupel": 941, "MetHail": 12, "PercentValidData": "22.69"}; get_percentile_nc.py: meltingLevelMslM = {'ave': 2769.0, 'min': 2600.0, 'max': 2900.0}
# 	volume_number: 1
# 	platform_type: fixed
# 	instrument_type: radar
# 	primary_axis: axis_z

# %%
xr.open_dataset(xband_files[0], engine='cfradial1')
# Out:
# <xarray.Dataset> Size: 525B
# Dimensions:              (sweep: 8, frequency: 1)
# Coordinates:
#   * frequency            (frequency) float32 4B 9.339e+09
# Dimensions without coordinates: sweep
# Data variables: (12/13)
#     sweep_fixed_angle    (sweep) float32 32B ...
#     sweep_group_name     (sweep) <U9 288B ...
#     volume_number        float64 8B ...
#     platform_type        |S32 32B ...
#     primary_axis         |S32 32B ...
#     status_str           |S1 1B ...
#     ...                   ...
#     time_coverage_start  |S32 32B ...
#     time_coverage_end    |S32 32B ...
#     latitude             float64 8B ...
#     longitude            float64 8B ...
#     altitude             float64 8B ...
#     altitude_agl         float64 8B ...
# Attributes: (12/14)
#     Conventions:         CF-1.7
#     version:             CF-Radial-1.4
#     title:               VOL_A
#     institution:
#     references:          Conversion software: Radx::SigmetRadxFile
#     source:              Sigmet IRIS software
#     ...                  ...
#     site_name:           Desio_Radar
#     scan_name:           VOL_A
#     scan_id:             0
#     platform_is_mobile:  false
#     ray_times_increase:  true
#     history:             Wed May 22 18:13:42 2024: ncap2 -Os fixed_angle  (:)...

# %%
xr.open_dataset(xband_files[0], engine="cfradial1")
# Out:
# <xarray.Dataset> Size: 525B
# Dimensions:              (sweep: 8, frequency: 1)
# Coordinates:
#   * frequency            (frequency) float32 4B 9.339e+09
# Dimensions without coordinates: sweep
# Data variables: (12/13)
#     sweep_fixed_angle    (sweep) float32 32B ...
#     sweep_group_name     (sweep) <U9 288B ...
#     volume_number        float64 8B ...
#     platform_type        |S32 32B ...
#     primary_axis         |S32 32B ...
#     status_str           |S1 1B ...
#     ...                   ...
#     time_coverage_start  |S32 32B ...
#     time_coverage_end    |S32 32B ...
#     latitude             float64 8B ...
#     longitude            float64 8B ...
#     altitude             float64 8B ...
#     altitude_agl         float64 8B ...
# Attributes: (12/14)
#     Conventions:         CF-1.7
#     version:             CF-Radial-1.4
#     title:               VOL_A
#     institution:
#     references:          Conversion software: Radx::SigmetRadxFile
#     source:              Sigmet IRIS software
#     ...                  ...
#     site_name:           Desio_Radar
#     scan_name:           VOL_A
#     scan_id:             0
#     platform_is_mobile:  false
#     ray_times_increase:  true
#     history:             Wed May 22 18:13:42 2024: ncap2 -Os fixed_angle  (:)...

# %%
groups = [
        i for i in list(dt.groups) if i.startswith("/sweep") if i not in ["/"]
    ]
groups[:3]
# Out:
# ['/sweep_0', '/sweep_1', '/sweep_2']

# %%
radars = {"cband": "/media/alfonso/drive/Laura/ERAD/20240522_MeteoSwiss_ARPA_Lombardia/Data/Cband/MonteLema", 
          "xband": "/media/alfonso/drive/Laura/ERAD/20240522_MeteoSwiss_ARPA_Lombardia/Data/Xband/DES_VOL_RAW",
         }

# %%
root = {}
for key in list(radars.keys()):
    print(key)
    erad_files = sorted(glob(f"{radars[key]}*.nc"))
    dt = xd.io.open_cfradial1_datatree(erad_files[0])
    groups = [
        i[1:] for i in list(dt.groups) if i.startswith("/sweep") if i not in ["/"]
    ]
    groups[:3]
    for group in groups:
        print(group)
        ds = xr.open_mfdataset(
            erad_files[:3],
            preprocess=fix_angle,
            engine="cfradial1",
            group=group,
            concat_dim="volume_time",
            combine="nested",
        ).xradar.georeference()
        root[f"{key}/{group}"] = ds
# Out:
# cband
# sweep_0
# sweep_1
# sweep_2
# sweep_3
# sweep_4
# sweep_5
# sweep_6
# sweep_7
# sweep_8
# sweep_9
# sweep_10
# sweep_11
# sweep_12
# sweep_13
# sweep_14
# sweep_15
# sweep_16
# sweep_17
# sweep_18
# sweep_19
# xband
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3 print(key)
#       4 erad_files = sorted(glob(f"{radars[key]}*.nc"))
# ----> 5 dt = xd.io.open_cfradial1_datatree(erad_files[0])
#       6 groups = [
#       7     i[1:] for i in list(dt.groups) if i.startswith("/sweep") if i not in ["/"]
#       8 ]
#       9 groups[:3]
#
# File ~/mambaforge/envs/kerchunk/lib/python3.12/site-packages/xradar/io/backends/cfradial1.py:355, in open_cfradial1_datatree(filename_or_obj, **kwargs)
#     349 DataTree(subgroup, name="georeferencing_correction", parent=dtree)
#     351 # return datatree with attached sweep child nodes
#     352 dtree = _attach_sweep_groups(
#     353     dtree,
#     354     list(
# --> 355         _get_sweep_groups(
#     356             ds,
#     357             sweep=sweep,
#     358             first_dim=first_dim,
#     359             optional=optional,
#     360             site_coords=site_coords,
#     361         ).values()
#     362     ),
#     363 )
#     365 return dtree
#
# File ~/mambaforge/envs/kerchunk/lib/python3.12/site-packages/xradar/io/backends/cfradial1.py:174, in _get_sweep_groups(obj, sweep, first_dim, optional, site_coords)
#     172 rslice = slice(0, current_ray_n_gates[0].values.astype(int))
#     173 ds = ds.isel(range=rslice)
# --> 174 ds = ds.isel(n_points=nslice)
#     175 ds = ds.stack(n_points=[dim0, "range"])
#     176 ds = ds.unstack("n_points")
#
# File ~/mambaforge/envs/kerchunk/lib/python3.12/site-packages/xarray/core/dataset.py:2977, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2973     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2975 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2976 # lists, or zero or one-dimensional np.ndarray's
# -> 2977 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    2979 variables = {}
#    2980 dims: dict[Hashable, int] = {}
#
# File ~/mambaforge/envs/kerchunk/lib/python3.12/site-packages/xarray/core/utils.py:824, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     822     invalid = indexers.keys() - set(dims)
#     823     if invalid:
# --> 824         raise ValueError(
#     825             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     826         )
#     828     return indexers
#     830 elif missing_dims == "warn":
#     831     # don't modify input
#
# ValueError: Dimensions {'n_points'} do not exist. Expected one or more of FrozenMappingWarningOnValuesAccess({'azimuth': 360, 'range': 416})

# %%
DataTree.from_dict(root)

# %%
root
# Out:
# {'cband/sweep_0': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 6...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 0 0 0
#      sweep_fixed_angle                    (volume_time) float32 12B -0.1923 .....
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_1': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 4...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 1 1 1
#      sweep_fixed_angle                    (volume_time) float32 12B 0.401 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_2': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 2...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 2 2 2
#      sweep_fixed_angle                    (volume_time) float32 12B 1.005 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_3': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 1.005 ... 1.005
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.181 ....
#      y                                    (azimuth, range) float64 1MB 249.9 ....
#      z                                    (azimuth, range) float64 1MB 1.63e+0...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 3 3 3
#      sweep_fixed_angle                    (volume_time) float32 12B 1.604 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_4': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB -...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 4 4 4
#      sweep_fixed_angle                    (volume_time) float32 12B 2.505 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_5': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 3...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 5 5 5
#      sweep_fixed_angle                    (volume_time) float32 12B 3.505 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_6': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 2...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 6 6 6
#      sweep_fixed_angle                    (volume_time) float32 12B 4.51 ... 4...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_7': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 16.0 ... 16.0
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.097 ....
#      y                                    (azimuth, range) float64 1MB 240.3 ....
#      z                                    (azimuth, range) float64 1MB 1.695e+...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 7 7 7
#      sweep_fixed_angle                    (volume_time) float32 12B 5.504 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_8': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 1...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 8 8 8
#      sweep_fixed_angle                    (volume_time) float32 12B 6.504 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_9': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 8.504 ... 8.504
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.157 ....
#      y                                    (azimuth, range) float64 1MB 247.2 ....
#      z                                    (azimuth, range) float64 1MB 1.663e+...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 9 9 9
#      sweep_fixed_angle                    (volume_time) float32 12B 7.493 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_10': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 7...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 10 10 10
#      sweep_fixed_angle                    (volume_time) float32 12B 8.504 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_11': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 5.504 ... 5.504
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.171 ....
#      y                                    (azimuth, range) float64 1MB 248.8 ....
#      z                                    (azimuth, range) float64 1MB 1.65e+0...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 11 11 11
#      sweep_fixed_angle                    (volume_time) float32 12B 9.503 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_12': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 3.505 ... 3.505
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.177 ....
#      y                                    (azimuth, range) float64 1MB 249.5 ....
#      z                                    (azimuth, range) float64 1MB 1.641e+...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 12 12 12
#      sweep_fixed_angle                    (volume_time) float32 12B 11.0 ... 11.0
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_13': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 1...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 13 13 13
#      sweep_fixed_angle                    (volume_time) float32 12B 13.0 ... 13.0
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_14': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 0...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 14 14 14
#      sweep_fixed_angle                    (volume_time) float32 12B 16.0 ... 16.0
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_15': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 4...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 15 15 15
#      sweep_fixed_angle                    (volume_time) float32 12B 20.01 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_16': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 3...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 16 16 16
#      sweep_fixed_angle                    (volume_time) float32 12B 25.01 ... ...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_17': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 2...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 17 17 17
#      sweep_fixed_angle                    (volume_time) float32 12B 30.0 ... 30.0
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_18': <xarray.Dataset> Size: 43MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (azimuth) float32 1kB 13.0 ... 13.0
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range) float64 1MB 2.125 ....
#      y                                    (azimuth, range) float64 1MB 243.5 ....
#      z                                    (azimuth, range) float64 1MB 1.682e+...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 18 18 18
#      sweep_fixed_angle                    (volume_time) float32 12B 35.0 ... 35.0
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>,
#  'cband/sweep_19': <xarray.Dataset> Size: 51MB
#  Dimensions:                              (volume_time: 3, azimuth: 360,
#                                            range: 492)
#  Coordinates:
#    * range                                (range) float32 2kB 250.0 ... 2.457e+05
#    * azimuth                              (azimuth) float32 1kB 0.5 1.5 ... 359.5
#      time                                 (volume_time, azimuth) datetime64[ns] 9kB ...
#      elevation                            (volume_time, azimuth) float32 4kB 9...
#      latitude                             float32 4B 46.04
#      longitude                            float32 4B 8.833
#      altitude                             float32 4B 1.626e+03
#    * volume_time                          (volume_time) datetime64[ns] 24B 202...
#      crs_wkt                              int64 8B 0
#      x                                    (azimuth, range, volume_time) float64 4MB ...
#      y                                    (azimuth, range, volume_time) float64 4MB ...
#      z                                    (volume_time, azimuth, range) float64 4MB ...
#  Data variables: (12/14)
#      reflectivity                         (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      signal_to_noise_ratio                (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      reflectivity_vv                      (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      differential_reflectivity            (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_cross_correlation_ratio  (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      uncorrected_differential_phase       (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      ...                                   ...
#      reflectivity_hh_clut                 (volume_time, azimuth, range) float64 4MB dask.array<chunksize=(1, 360, 492), meta=np.ndarray>
#      sweep_number                         (volume_time) int64 24B 19 19 19
#      sweep_fixed_angle                    (volume_time) float32 12B 40.0 ... 3...
#      sweep_mode                           (volume_time) <U20 240B 'azimuth_sur...
#      pulse_width                          (volume_time, azimuth) timedelta64[ns] 9kB dask.array<chunksize=(1, 360), meta=np.ndarray>
#      nyquist_velocity                     (volume_time, azimuth) float32 4kB dask.array<chunksize=(1, 360), meta=np.ndarray>}

# %%
fig, ax = plt.subplots()
ds.isel(volume_time=1).reflectivity.plot(x="x", y="y", cmap="ChaseSpectral", vmin=-10, vmax=50)

# %%
ds.to_zarr()

# %%
ds.reflectivity.hvplot.quadmesh(x="x", 
                                y="y", 
                                groupby="volume_time", 
                                widget_type="scrubber",
                                widget_location="bottom",
                                clim=(-10, 50),
                                cmap="ChaseSpectral"
                                # rasterize=True, 
                               )
