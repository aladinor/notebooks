# %%
import xarray as xr

# %%
path = "../raw2zarr/zarr/KVNX.zarr"

# %%
dtree = xr.open_datatree(
    path, 
    engine="zarr",
    chunks={}
)

# %%
list(dtree.children)
# Out:
# ['VCP-11', 'VCP-12', 'VCP-212', 'VCP-32']

# %%
list(dtree["VCP-212"].groups)
# Out:
# ['/VCP-212',
#  '/VCP-212/georeferencing_correction',
#  '/VCP-212/radar_calibration',
#  '/VCP-212/radar_parameters',
#  '/VCP-212/sweep_0',
#  '/VCP-212/sweep_1',
#  '/VCP-212/sweep_10',
#  '/VCP-212/sweep_11',
#  '/VCP-212/sweep_12',
#  '/VCP-212/sweep_13',
#  '/VCP-212/sweep_14',
#  '/VCP-212/sweep_15',
#  '/VCP-212/sweep_16',
#  '/VCP-212/sweep_2',
#  '/VCP-212/sweep_3',
#  '/VCP-212/sweep_4',
#  '/VCP-212/sweep_5',
#  '/VCP-212/sweep_6',
#  '/VCP-212/sweep_7',
#  '/VCP-212/sweep_8',
#  '/VCP-212/sweep_9']

# %%
dtree
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /VCP-11
# │   │   Dimensions:              (vcp_time: 41)
# │   │   Coordinates:
# │   │     * vcp_time             (vcp_time) datetime64[ns] 328B 2011-05-20T15:53:00 ....
# │   │   Data variables:
# │   │       altitude             (vcp_time) int64 328B dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       instrument_type      (vcp_time) <U5 820B dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       latitude             (vcp_time) float64 328B dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       longitude            (vcp_time) float64 328B dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       platform_type        (vcp_time) <U5 820B dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       time_coverage_end    (vcp_time) <U20 3kB dask.array<chunksize=(1,), meta=np.ndarray>
# │   │       time_coverage_start  (vcp_time) <U20 3kB dask.array<chunksize=(1,), meta=np.ndarray>
# ...

# %%
dtree["VCP-212/sweep_0"].DBZH
# Out:
# <xarray.DataArray 'DBZH' (vcp_time: 59, azimuth: 720, range: 1832)> Size: 623MB
# dask.array<open_dataset-DBZH, shape=(59, 720, 1832), dtype=float64, chunksize=(1, 180, 458), chunktype=numpy.ndarray>
# Coordinates:
#   * vcp_time   (vcp_time) datetime64[ns] 472B 2011-05-20T19:19:02 ... 2011-05...
#     altitude   int64 8B ...
#   * azimuth    (azimuth) float64 6kB 0.25 0.75 1.25 1.75 ... 358.8 359.2 359.8
#     crs_wkt    int64 8B ...
#     elevation  (azimuth) float64 6kB dask.array<chunksize=(720,), meta=np.ndarray>
#     latitude   float64 8B ...
#     longitude  float64 8B ...
#   * range      (range) float32 7kB 2.125e+03 2.375e+03 ... 4.596e+05 4.599e+05
#     time       (azimuth) datetime64[ns] 6kB dask.array<chunksize=(720,), meta=np.ndarray>
#     x          (azimuth, range) float64 11MB dask.array<chunksize=(180, 458), meta=np.ndarray>
#     y          (azimuth, range) float64 11MB dask.array<chunksize=(180, 458), meta=np.ndarray>
# ...
