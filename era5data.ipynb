# %%
from arraylake import Client
import xarray as xr
import numpy as np

# %%
client = Client()
client.login()
# Out:
# 🔓 Successfully refreshed tokens!
# > Token stored at /home/alfonso/.arraylake/token.json
# ╭──────────────────────────────────────────────── 👤 User Details ────────────────────────────────────────────────╮
# │ Name: Alfonso Ladino-Rincon                                                                                     │
# │ Email: alfonso@earthmover.io                                                                                    │
# │ Id: c331861f-0725-43ad-85df-7217ef584add                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 🔓 Successfully logged in!
# > Token stored at /home/alfonso/.arraylake/token.json
# ╭──────────────────────────────────────────────── 👤 User Details ────────────────────────────────────────────────╮
# │ Name: Alfonso Ladino-Rincon                                                                                     │
# ...

# %%
repo = client.get_repo("earthmover-demos/alfonsos-test-repo")

# %%
session = repo.readonly_session("main")

# %%
# %%time
ds = xr.open_dataset(
    session.store, 
    engine="zarr", 
    consolidated=False, 
    zarr_format=3, 
    chunks=None
)
# Out:
# CPU times: user 23.5 ms, sys: 2.85 ms, total: 26.3 ms
# Wall time: 904 ms

# %%
display(ds)
# Out:
# <xarray.Dataset> Size: 509GB
# Dimensions:    (time: 8760, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 70kB 1999-01-01 ... 1999-12-31T23:00:00
# Data variables: (12/14)
#     blh        (time, latitude, longitude) float32 36GB ...
#     fsr        (time, latitude, longitude) float32 36GB ...
#     mslp       (time, latitude, longitude) float32 36GB ...
#     d2         (time, latitude, longitude) float32 36GB ...
#     sp         (time, latitude, longitude) float32 36GB ...
#     sst        (time, latitude, longitude) float32 36GB ...
#     ...         ...
#     u10        (time, latitude, longitude) float32 36GB ...
#     tcw        (time, latitude, longitude) float32 36GB ...
#     cape       (time, latitude, longitude) float32 36GB ...
# ...

# %%
ds.nbytes / 1024**3
# Out:
# 474.3403771594167
